# %%
import numpy as np 
import pandas as pd

# %%
latlong = pd.read_csv(r'C:\Users\parth\OneDrive\Desktop\DSMP Task\DSMP Paid\8-Session on Plotly Express\Project\dataset\district wise centroids.csv')
census = pd.read_csv(r'C:\Users\parth\OneDrive\Desktop\DSMP Task\DSMP Paid\8-Session on Plotly Express\Project\dataset\india-districts-census-2011.csv')

# %%
print(latlong.shape)
print(census.shape)
# Out:
# (594, 4)
# (640, 118)

# %%
census = census[['District code','District name','Population','Male','Female','Literate','Households_with_Internet','Housholds_with_Electric_Lighting']]

# %%
census.head(2)
# Out:
#    District code District name  Population    Male  Female  Literate  \
# 0              1       Kupwara      870354  474190  396164    439654
# 1              2        Badgam      753745  398041  355704    335649
#
#    Households_with_Internet  Housholds_with_Electric_Lighting
# 0                       762                             83071
# 1                      1999                             90190

# %%
latlong.head(2)
# Out:
#                  State         District   Latitude  Longitude
# 0  Andaman and Nicobar  Andaman Islands  12.382571  92.822911
# 1  Andaman and Nicobar  Nicobar Islands   7.835291  93.511601

# %%
final_df = latlong.merge(census,left_on='District',right_on='District name').drop(columns='District name')

# %%
final_df['sex_ratio'] = round(final_df['Female']/final_df['Male']*1000)

# %%
final_df['literacy_rate'] = round((final_df['Literate']/final_df['Population'])*100)

# %%
final_df = final_df.drop(columns=['Male','Female','Literate'])

# %%
final_df.to_csv('india.csv',index=False)

# %%
final_df.head(1)
# Out:
#             State  District   Latitude  Longitude  District code  Population  \
# 0  Andhra Pradesh  Adilabad  19.284514  78.813212            532     2741239
#
#    Households_with_Internet  Housholds_with_Electric_Lighting  sex_ratio  \
# 0                      5512                            566108     1001.0
#
#    literacy_rate
# 0           54.0

# %%
df = final_df

# %%
list_of_india = list(df['State'].unique())

# %%
list_of_india.insert(0,'Overall India')

# %%
list_of_india
# Out:
# ['Overall India',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Daman and Diu',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttaranchal',
#  'West Bengal']

# %%
sorted(df.columns[5:])
# Out:
# ['Households_with_Internet',
#  'Housholds_with_Electric_Lighting',
#  'Population',
#  'literacy_rate',
#  'sex_ratio']

# %%
import plotly.express as px

# %%
fig = px.scatter_mapbox(df,lat='Latitude',lon='Longitude',zoom=3,mapbox_style='carto-positron')
fig.show()
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_29420\929842762.py:1: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
